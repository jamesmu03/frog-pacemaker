# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json

# %%
# Load Data
dataFilePaths = [
    r"..\outputs\procedure2output.csv",  # df0
    r"..\outputs\10%VarPro2.csv",  # df1
    r"..\outputs\finalDatawpacingatLRI90BPM.csv",  # df2
    r"..\outputs\finalDatawpacingatLRI120BPM.csv",  # df3
    r"..\outputs\finalDatawpacingatLRI180BPM.csv",  # df4
]

for i, dataFilePath in enumerate(dataFilePaths):  # Read Datas
    globals()[f"df{i}"] = pd.read_csv(dataFilePath)

for i in range(5):  # Set timestamp to 0 at start
    timestampStart = globals()[f"df{i}"]["timestamp(ms)"].iloc[0]
    globals()[f"df{i}"]["timestamp(ms)"] = (
        globals()[f"df{i}"]["timestamp(ms)"] - timestampStart
    )
    "timestamp(ms),ECG_comp,Detetcted R wave,ECG_amp,"
for i in range(5):
    globals()[f"df{i}_ecg_comp"] = globals()[f"df{i}"]["ECG_comp"]
    globals()[f"df{i}_detected_r_wave"] = globals()[f"df{i}"]["Detetcted_R_wave"]
    globals()[f"df{i}_ecg_amp"] = globals()[f"df{i}"]["ECG_amp"]
    
    globals()[f"df{i}_time"] = np.linspace(0, globals()[f"df{i}"]["timestamp(ms)"].iloc[-1], len(globals()[f"df{i}_ecg_comp"]))
    globals()[f"df{i}_time_sec"] = globals()[f"df{i}_time"] / 1000
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\tools\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Detetcted_R_wave'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 21
#      19 for i in range(5):
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 40
#      37 plt.show()
#      39 fig = plt.figure()
# ---> 40 plt.plot(df["timestamp(ms)"], df["ECG_amp"], label="ECG Amp")
#      41 plt.plot(df["timestamp(ms)"], df["ECG_comp"], label="ECG Comp")
#      42 plt.title("Procedure 2 Output")
#
# NameError: name 'df' is not defined
